# %%
# !pip install h2o
# Out:
# Requirement already satisfied: h2o in e:\anaconda\lib\site-packages (3.36.0.3)
# Requirement already satisfied: tabulate in e:\anaconda\lib\site-packages (from h2o) (0.8.9)
# Requirement already satisfied: requests in e:\anaconda\lib\site-packages (from h2o) (2.27.1)
# Requirement already satisfied: future in e:\anaconda\lib\site-packages (from h2o) (0.18.2)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\lib\site-packages (from requests->h2o) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\anaconda\lib\site-packages (from requests->h2o) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in e:\anaconda\lib\site-packages (from requests->h2o) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\lib\site-packages (from requests->h2o) (3.3)

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in e:\anaconda\lib\site-packages (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in e:\anaconda\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\anaconda\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: numpy>=1.17 in e:\anaconda\lib\site-packages (from matplotlib) (1.22.2)
# Requirement already satisfied: pillow>=6.2.0 in e:\anaconda\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\lib\site-packages (from matplotlib) (4.29.1)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in e:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\PC\\Downloads\\Capstone'

# %%
# Task 1 & 2
# Try the explain the relation between attributes and the prediction on Bike rental dataset
# Dataset: http://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset#
# You can use the code from the above blocks.

import h2o
from h2o.automl import H2OAutoML
import os 

h2o.init()

# Import data
f = os.path.join(os.getcwd(),"Store_ProcessedData.csv")
df = h2o.import_file(f)

# Reponse column
y = "No of Users Purchased"

# Split into train & test
splits = df.split_frame(ratios = [0.8], seed = 1)
train = splits[0]
test = splits[1]

# Run AutoML for 1 minute
aml = H2OAutoML(max_runtime_secs=60, seed=1)
aml.train(y=y, training_frame=train)

# Explain leader model & compare with all AutoML models
exa = aml.explain(test)

# Explain a single H2O model (e.g. leader model from AutoML)
exm = aml.leader.explain(test)

# Explain a generic list of models
# use h2o.explain as follows:
# exl = h2o.explain(model_list, test)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ; OpenJDK 64-Bit Server VM 18.9 (build 11.0.13+8, mixed mode)
#   Starting server from E:\anaconda\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\PC\AppData\Local\Temp\tmp0rdysfmy
#   JVM stdout: C:\Users\PC\AppData\Local\Temp\tmp0rdysfmy\h2o_PC_started_from_python.out
#   JVM stderr: C:\Users\PC\AppData\Local\Temp\tmp0rdysfmy\h2o_PC_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       Asia/Kolkata
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.0.3
# H2O_cluster_version_age:    1 month and 6 days
# H2O_cluster_name:           H2O_from_python_PC_99oggh
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.986 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.8.8 final
# --------------------------  -----------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 18:31:32.949: AutoML: XGBoost is not available; skipping it.
# 18:31:32.973: Step 'best_of_family_xgboost' not defined in provider 'StackedEnsemble': skipping it.
# 18:31:32.973: Step 'all_xgboost' not defined in provider 'StackedEnsemble': skipping it.
#
# ███████████████████████████████████████████████████████████████| (done) 100%
# # Leaderboard
# > Leaderboard shows models with their metrics. When provided with H2OAutoML object, the leaderboard shows 5-fold cross-validated metrics by default (depending on the H2OAutoML settings), otherwise it shows metrics computed on the frame. At most 20 models are shown by default.
# <table>
# <thead>
# <tr><th>model_id                                               </th><th style="text-align: right;">  mean_residual_deviance</th><th style="text-align: right;">   rmse</th><th style="text-align: right;">    mse</th><th style="text-align: right;">    mae</th><th style="text-align: right;">   rmsle</th><th style="text-align: right;">  training_time_ms</th><th style="text-align: right;">  predict_time_per_row_ms</th><th>algo           </th></tr>
# </thead>
# <tbody>
# <tr><td>GLM_1_AutoML_1_20220322_183132                         </td><td style="text-align: right;">                 484.916</td><td style="text-align: right;">22.0208</td><td style="text-align: right;">484.916</td><td style="text-align: right;">19.093 </td><td style="text-align: right;">0.389239</td><td style="text-align: right;">               659</td><td style="text-align: right;">                 0.078541</td><td>GLM            </td></tr>
# <tr><td>StackedEnsemble_AllModels_1_AutoML_1_20220322_183132   </td><td style="text-align: right;">                 485.038</td><td style="text-align: right;">22.0236</td><td style="text-align: right;">485.038</td><td style="text-align: right;">19.0954</td><td style="text-align: right;">0.389269</td><td style="text-align: right;">               350</td><td style="text-align: right;">                 0.003986</td><td>StackedEnsemble</td></tr>
# <tr><td>StackedEnsemble_BestOfFamily