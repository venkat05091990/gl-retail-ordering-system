# %% [markdown]
# # Reading the data into python

# %%
# Supressing the warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
# parameters
current_time=''
batch_id=''
source_data=''
source_notebook=''
preprocessed_data=''
unprocessed_data=''

# %%
# update the batch status  to 1 (Running)

# %%
# Reading the dataset
import pandas as pd
import numpy as np

inventory_df = pd.read_excel(open(source_data, 'rb'),
              sheet_name='Sheet1')  

inventory_df.head()
# Out:
#                       Category                         Sub Category  \
# 0  Food Grains, Oli and Masala                                 Rava
# 1  Food Grains, Oli and Masala                                Flour
# 2  Food Grains, Oli and Masala                              Staples
# 3                Gourmet Foods  Tomato Ketchup , Sauces and Spreads
# 4                Personal Care                             Ear Buds
#
#               Brand Name  Product Rating                    Product Name  \
# 0      24 Mantra Organic               3  TWENTY FOUR ORG IDLY RAVA 500g
# 1      24 Mantra Organic               3     TWENTY FOUR RAGI FLOUR 500g
# 2      24 Mantra Organic               3   TWENTY FOUR ORG RED POHA 500g
# 3        American Garden               3   A G CHUNKY PEANUT BUTTER 510g
# 4  Johnsons and Johnsons               4    A-ONE EAR BUDS JAR SMALL 15g
#
#                         Name  Weight   MRP/Unit  Qnty  Unit Qnty  Cost Price  \
# 0  TWENTY FOUR ORG IDLY RAVA     500g      55.0   2.0        1.0       83.78
# 1     TWENTY FOUR RAGI FLOUR     500g      70.0   2.0        1.0      106.64
# 2   TWENTY FOUR ORG RED POHA     500g      75.0   2.0        1.0      119.97
# 3   A G CHUNKY PEANUT BUTTER     510g     399.0   2.0        1.0      608.96
# 4   A-ONE EAR BUDS JAR SMALL      15g      55.0   6.0        1.0      221.52
#
#     Product ID
# 0  202212001.0
# 1  202212002.0
# 2  202212003.0
# 3  202212004.0
# 4  202212005.0

# %%
print('Shape before deleting duplicate values:', inventory_df.shape)

# Removing duplicate rows if any
inventory_df = inventory_df.drop_duplicates()
print('Shape After deleting duplicate values:', inventory_df.shape)

# Printing sample data
inventory_df.sample(5)
# Out:
# Shape before deleting duplicate values: (1022, 12)
# Shape After deleting duplicate values: (1022, 12)
#           Category                                       Sub Category  \
# 920      Household  Dry Detergent , Liquid Detergent,  Detergent W...
# 30      Household                                        Air Freshner
# 922      Household  Dry Detergent , Liquid Detergent,  Detergent W...
# 747  Gourmet Foods                               Cookies and Biscuits
# 429     Household   Disinfectants Liquid , Wipes, Floor Cleaner an...
#
#     Brand Name  Product Rating                       Product Name  \
# 920       Surf               4         SURF EXCEL QUICK WASH 1 kg
# 30      Godrej               4  AER POCKET VOILET VALLEY BLOOM 5g
# 922       Surf               5         SURF EXCEL QUICK WASH 500g
# 747      Parle               3               PARLE H&S CHOCO 120g
# 429     Harpic               4  HARPIC BATHROOM CLNR 500 ml LEMON
#
#                                Name        Weight   MRP/Unit  Qnty  Unit Qnty  \
# 920           SURF EXCEL QUICK WASH           1 kg     180.0   4.0        1.0
# 30   AER POCKET VOILET VALLEY BLOOM             5g      55.0  15.0        1.0
# 922           SURF EXCEL QUICK WASH           500g      90.0   3.0        1.0
# 747                 PARLE H&S CHOCO           120g      30.0  15.0        1.0
# 429            HARPIC BATHROOM CLNR   500 ml LEMON       0.0   3.0        1.0
#
#      Cost Price   Product ID
# 920      535.60  202212943.0
# 30       599.25  202212031.0
# 922      195.75  202212945.0
# 747      340.50  202212759.0
# 429      206.58  202212430.0

# %% [markdown]
# # Defining the problem statement

# %% [markdown]
# #### Create a predictive model which gives relevant products recommendations
#
# Predictors: Category, Sub Category, Brand Name, Product Rating, Name

# %% [markdown]
# # Basic Data Exploration

# %%
# Looking at the sample rows in the data
inventory_df.sample(5)
# Out:
#                         Category  \
# 813                    Beverages
# 663  Food Grains, Oli and Masala
# 844                       Beauty
# 411                       Beauty
# 914                    Household
#
#                                           Sub Category        Brand Name  \
# 813                                       Fruit Juices               Red
# 663                                 Instant Staple Mix               Mtr
# 844                                          Skin Care           Santoor
# 411                               Hair Care & Hair Oil  Head & Shoulders
# 914  Dry Detergent , Liquid Detergent,  Detergent W...              Surf
#
#      Product Rating                    Product Name  \
# 813               2  RED LABEL NATURALCARE TEA 500g
# 663               5          MTR VEGETABLE UPMA 60g
# 844               5  SANTOOR HAND WASH FRESH 750 ml
# 411               5    H&S SMOOTH & SILKY SH 180 ml
# 914               5             SURF EXCEL BAR 150g
#
#                           Name  Weight   MRP/Unit  Qnty  Unit Qnty  \
# 813  RED LABEL NATURALCARE TEA     500g     275.0   4.0        1.0
# 663         MTR VEGETABLE UPMA      60g      20.0  10.0        1.0
# 844    SANTOOR HAND WASH FRESH   750 ml     110.0   2.0        1.0
# 411      H&S SMOOTH & SILKY SH   180 ml     150.0   2.0        1.0
# 914             SURF EXCEL BAR     150g      16.0   6.0        1.0
#
#      Cost Price   Product ID
# 813      943.68  202212828.0
# 663      111.70  202212668.0
# 844      175.52  202212860.0
# 411      235.40  202212412.0
# 914       70.50  202212937.0

# %%
# Observing the summarized information of data
# Data types, Missing values based on number of non-null values Vs total rows etc.
# Remove those variables from data which have too many missing values (Missing Values > 30%)
# Remove Qualitative variables which cannot be used in Machine Learning
inventory_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1022 entries, 0 to 1021
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        1022 non-null   object
#  1   Sub Category    1022 non-null   object
#  2   Brand Name      1022 non-null   object
#  3   Product Rating  1022 non-null   int64
#  4    Product Name   1022 non-null   object
#  5   Name            1022 non-null   object
#  6   Weight          1022 non-null   object
#  7   MRP/Unit        1021 non-null   float64
#  8   Qnty            1021 non-null   float64
#  9   Unit Qnty       1020 non-null   float64
#  10  Cost Price      1021 non-null   float64
#  11  Product ID      1021 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 103.8+ KB

# %%
# Looking at the descriptive statistics of the data
inventory_df.describe(include='all')
# Out:
#        Category Sub Category Brand Name  Product Rating  \
# count      1022         1022       1022     1022.000000
# unique       18           70        253             NaN
# top      Beauty    Skin Care    Colgate             NaN
# freq        216          117         49             NaN
# mean        NaN          NaN        NaN        3.195695
# std         NaN          NaN        NaN        1.233257
# min         NaN          NaN        NaN        1.000000
# 25%         NaN          NaN        NaN        2.000000
# 50%         NaN          NaN        NaN        3.000000
# 75%         NaN          NaN        NaN        4.000000
# max         NaN          NaN        NaN        5.000000
#
#                           Product Name               Name  Weight   \
# count                             1022                1022    1022
# unique                             984                 906     391
# top     FIAMA SHWRGEL LEMONGRAS 500 ml  MAGGI MSL NOODLES     100g
# freq                                 2                   7      40
# mean                               NaN                 NaN     NaN
# std                                NaN                 NaN     NaN
# min                                NaN                 NaN     NaN
# 25%                                NaN                 NaN     NaN
# 50%                                NaN                 NaN     NaN
# 75%                                NaN                 NaN     NaN
# max                                NaN                 NaN     NaN
#
#            MRP/Unit         Qnty    Unit Qnty   Cost Price    Product ID
# count   1021.000000  1021.000000  1020.000000  1021.000000  1.021000e+03
# unique          NaN          NaN          NaN          NaN           NaN
# top             NaN          NaN          NaN          NaN           NaN
# freq            NaN          NaN          NaN          NaN           NaN
# mean     109.081293     5.281097     2.615686   292.178296  2.022125e+08
# std      108.344124     7.932703     9.959553   262.688841  3.026632e+02
# min        0.000000     1.000000     1.000000    15.680000  2.022120e+08
# 25%       37.000000     2.000000     1.000000   147.920000  2.022123e+08
# 50%       75.000000     3.000000     1.000000   222.620000  2.022125e+08
# 75%      150.000000     6.000000     1.000000   340.500000  2.022128e+08
# max      999.000000   100.000000   130.000000  3028.500000  2.022130e+08

# %%
# Finding unique values for each column
# TO understand which column is categorical and which one is Continuous
# Typically if the numer of unique values are < 20 then the variable is likely to be a category otherwise continuous
inventory_df.nunique()
# Out:
# Category            18
# Sub Category        70
# Brand Name         253
# Product Rating       5
#  Product Name      984
# Name               906
# Weight             391
# MRP/Unit           191
# Qnty                30
# Unit Qnty           21
# Cost Price         818
# Product ID        1021
# dtype: int64

# %% [markdown]
# # Basic Data Exploration Results
#
# Based on the basic exploration above, we can create a simple report of the data, noting down the observations regaring each column. Hence, creating a initial roadmap for further analysis.
#
# The selected columns in this step are not final, further study will be done and then a final list will be created.
#
# - Category     : Selected. Categorical.
# - Sub Category : Selected. Categorical.
# - Brand Name   : Selected. Categorical.
# - Product Name: Selected. Categorical.
# - Name         : Selected. Categorical.
# - Weight       : Selected. Continuous.
# - MRP/Unit     : Selected. Continuous.
# - Qnty         : Selected. Continuous.
# - Unit Qnty    : Selected. Continuous.
# - Cost Price   : Selected. Continuous.
# - Product ID   : Selected. Continuous.
# - Product rating : Selected. Continuous.

# %% [markdown]
# # Visual Exploratory Data Analysis
#
# Categorical variables: Bar plot
#
# Continuous variables: Histogram

# %% [markdown]
# ## Visualize distribution of all the Categorical Predictor variables in the data using bar plots
# We can spot a categorical variable in the data by looking at the unique values in them. Typically a categorical variable contains less than 20 Unique values AND there is repetition of values, which means the data can be grouped by those unique values.

# %%
# Plotting multiple bar charts at once for categorical variables
# Since there is no default function which can plot bar charts for multiple columns at once
# we are defining our own function for the same

def PlotBarCharts(inpData, colsToPlot):
    # %matplotlib inline
    
    import matplotlib.pyplot as plt
    
    # Generating multiple subplots
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(50,5))
    fig.suptitle('Bar charts of: '+ str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
        inpData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

# %%
#####################################################################
# Calling the function for 5 columns
PlotBarCharts(inpData=inventory_df, 
              colsToPlot=['Category', 'Sub Category'])

# %%
#####################################################################
# Calling the function for 5 columns
PlotBarCharts(inpData=inventory_df, 
              colsToPlot=['Brand Name', 'Name '])

# %% [markdown]
# # Bar Charts Interpretation
# These bar charts represent the frequencies of each category in the Y-axis and the category names in the X-axis.
#
# In this data, all the categorical columns except "Brand Name", "Name" and "Product Name" have satisfactory distribution for machine learning.

# %% [markdown]
# # Visualize distribution of all the Continuous Predictor variables in the data using histograms

# %%
# Plotting histograms of multiple columns together

inventory_df.hist(['MRP/Unit', 'Qnty', 'Product Rating'], figsize=(10, 5))
# Out:
# array([[<AxesSubplot:title={'center':'MRP/Unit'}>,
#         <AxesSubplot:title={'center':'Qnty'}>],
#        [<AxesSubplot:title={'center':'Product Rating'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# Plotting histograms of multiple columns together

inventory_df.hist(['Unit Qnty', 'Cost Price', 'Product ID'], figsize=(18,10))
# Out:
# array([[<AxesSubplot:title={'center':'Unit Qnty'}>,
#         <AxesSubplot:title={'center':'Cost Price'}>],
#        [<AxesSubplot:title={'center':'Product ID'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# # Histogram Interpretation
# Histograms shows us the data distribution for a single continuous variable.
#
# The ideal outcome for histogram is a bell curve or slightly skewed bell curve. If there is too much skewness, then outlier treatment should be done and the column should be re-examined, if that also does not solve the problem then only reject the column.
#
# Selected Continuous Variables:
#
# - MRP/Unit   : Selected. Slightly skewed distribution, acceptable.
# - Qnty       : Selected. Slightly skewed distribution, acceptable.
# - Unit Qnty  : Selected. Skewed distribution, not acceptable.
# - Cost Price : Selected. Slightly skewed distribution, acceptable.

# %% [markdown]
# # Outlier treatment
# Outliers are extreme values in the data which are far away from most of the values. You can see them as the tails in the histogram.
#
# Outlier must be treated one column at a time. As the treatment will be slightly different for each column.
#
# Why I should treat the outliers?
#
# Outliers bias the training of machine learning models. As the algorithm tries to fit the extreme value, it goes away from majority of the data.
#
# There are below two options to treat outliers in the data.
#
# - Option-1: Delete the outlier Records. Only if there are just few rows lost.
# - Option-2: Impute the outlier values with a logical business value
#
# In this data all the continuous variables have slightly skewed distribution, which is acceptable, hence no outlier treatment is required.

# %% [markdown]
# # Missing values treatment
# Missing values are treated for each column separately.
#
# If a column has more than 30% data missing, then missing value treatment cannot be done. That column must be rejected because too much information is missing.
#
# There are below options for treating missing values in data.
#
# - Delete the missing value rows if there are only few records
# - Impute the missing values with MEDIAN value for continuous variables
# - Impute the missing values with MODE value for categorical variables
# - Interpolate the values based on nearby values
# - Interpolate the values based on business logic

# %%
# Finding how many missing values are there for each column
inventory_df.isnull().sum()
# Out:
# Category          0
# Sub Category      0
# Brand Name        0
# Product Rating    0
#  Product Name     0
# Name              0
# Weight            0
# MRP/Unit          1
# Qnty              1
# Unit Qnty         2
# Cost Price        1
# Product ID        1
# dtype: int64

# %%
inventory_df.replace('', np.nan, inplace=True)

# %%
inventory_df.dropna(inplace=True)

# Finding how many missing values are there for each column
inventory_df.isnull().sum()
# Out:
# Category          0
# Sub Category      0
# Brand Name        0
# Product Rating    0
#  Product Name     0
# Name              0
# Weight            0
# MRP/Unit          0
# Qnty              0
# Unit Qnty         0
# Cost Price        0
# Product ID        0
# dtype: int64

# %% [markdown]
# All the missing values are removed now.

# %% [markdown]
# # Data Cleansing

# %%
# Removing the leading and trailing spaces of columns
inventory_df.columns = inventory_df.columns.str.strip()

# %%
inventory_df.columns
# Out:
# Index(['Category', 'Sub Category', 'Brand Name', 'Product Rating',
#        'Product Name', 'Name', 'Weight', 'MRP/Unit', 'Qnty', 'Unit Qnty',
#        'Cost Price', 'Product ID'],
#       dtype='object')

# %% [markdown]
# # Find Correalation between attributes

# %%
# To find the correlation among
# the columns using pearson method
inventory_df.corr(method ='pearson')
# Out:
#                 Product Rating  MRP/Unit      Qnty  Unit Qnty  Cost Price  \
# Product Rating        1.000000  0.026425 -0.041177   0.012760   -0.021448
# MRP/Unit              0.026425  1.000000 -0.228106  -0.079974    0.531658
# Qnty                 -0.041177 -0.228106  1.000000  -0.078142    0.234813
# Unit Qnty             0.012760 -0.079974 -0.078142   1.000000   -0.046926
# Cost Price           -0.021448  0.531658  0.234813  -0.046926    1.000000
# Product ID           -0.015786 -0.045739  0.022680  -0.019392   -0.047321
#
#                 Product ID
# Product Rating   -0.015786
# MRP/Unit         -0.045739
# Qnty              0.022680
# Unit Qnty        -0.019392
# Cost Price       -0.047321
# Product ID        1.000000

# %% [markdown]
# # Save the file into local machine

# %%
inventory_df.to_csv(preprocessed_data , index = False)

# %%
# update the batch status  to 2 (Completed Successfully)
